# %%
import numpy as np
import pandas as pd
responseInjectionPath = "./ModbusRTUfeatureSetsV2/Multiclass FeatureSets/MulticlasCommandInjectionV2.csv"

data = pd.read_csv(responseInjectionPath)

# %%
data.head()
# Out:
#   Address CommandResponse     ControlMode          ControlScheme   CRC  \
# 0     0x4         Command  OffControlMode  SolenoidControlScheme  3441
# 1     0x4         Command               X                      X  3245
# 2     0x4         Command  OffControlMode  SolenoidControlScheme  3441
# 3     0x4         Command               X                      X  3245
# 4     0x4         Command  OffControlMode  SolenoidControlScheme  3441
#
#    DataLength FunctionCode InvalidDataLength InvalidFunctionCode  \
# 0          41         0x10                 X                   X
# 1           4          0x3                 X                   X
# 2          41         0x10                 X                   X
# 3           4          0x3                 X                   X
# 4          41         0x10                 X                   X
#
#    PIDCycleTime   ...    SolenoidState  TimeInterval  deltaPIDCycleTime  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28344 entries, 0 to 28343
# Data columns (total 27 columns):
# Address                28344 non-null object
# CommandResponse        28344 non-null object
# ControlMode            28344 non-null object
# ControlScheme          28344 non-null object
# CRC                    28344 non-null int64
# DataLength             28344 non-null int64
# FunctionCode           28344 non-null object
# InvalidDataLength      28344 non-null object
# InvalidFunctionCode    28344 non-null object
# PIDCycleTime           28344 non-null float64
# PIDDeadband            28344 non-null float64
# PIDGain                28344 non-null float64
# PIDRate                28344 non-null int64
# PIDReset               28344 non-null float64
# PipelinePSI            28344 non-null int64
# PumpState              28344 non-null object
# SetPoint               28344 non-null float64
# SolenoidState          28344 non-null object
# ...

# %%
from collections import Counter

Counter(data[' Label'])
# Out:
# Counter({'AddressScan': 2,
#          'FunctionCodeScan': 9,
#          'Good': 28086,
#          'IllegalSetpoint': 198,
#          'PIDmodification': 49})
