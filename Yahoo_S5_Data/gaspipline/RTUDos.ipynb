# %%
import  numpy as np 
import pandas as pd

# %%
DosAttackPath = "./ModbusRTUfeatureSetsV2/DoS Data FeatureSet/modbusRTU_DoSResponseInjectionV2.csv"

data = pd.read_csv(DosAttackPath)

# %%
data.head()
# Out:
#   Address CommandResponse ControlMode ControlScheme   CRC  DataLength  \
# 0     0x4        Response           X             X  4536           4
# 1     0x4        Response           X             X  3439          19
# 2     0x4        Response           X             X  4536           4
# 3     0x4        Response           X             X  3533          19
# 4     0x4        Response           X             X  4536           4
#
#   FunctionCode InvalidDataLength InvalidFunctionCode  PIDCycleTime   ...    \
# 0         0x10                 X                   X           0.0   ...
# 1          0x3                 X                   X           0.0   ...
# 2         0x10                 X                   X           0.0   ...
# 3          0x3                 X                   X           0.0   ...
# 4         0x10                 X                   X           0.0   ...
#
#       SolenoidState  TimeInterval  deltaPIDCycleTime  deltaPIDDeadband  \
# ...

# %%
from collections import Counter

Counter(data[' Label'])
# Out:
# Counter({'Bad': 873, 'Good': 28070})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28943 entries, 0 to 28942
# Data columns (total 27 columns):
# Address                28943 non-null object
# CommandResponse        28943 non-null object
# ControlMode            28943 non-null object
# ControlScheme          28943 non-null object
# CRC                    28943 non-null int64
# DataLength             28943 non-null int64
# FunctionCode           28943 non-null object
# InvalidDataLength      28943 non-null object
# InvalidFunctionCode    28943 non-null object
# PIDCycleTime           28943 non-null float64
# PIDDeadband            28943 non-null float64
# PIDGain                28943 non-null float64
# PIDRate                28943 non-null float64
# PIDReset               28943 non-null float64
# PipelinePSI            28943 non-null float64
# PumpState              28943 non-null object
# SetPoint               28943 non-null float64
# SolenoidState          28943 non-null object
# ...
