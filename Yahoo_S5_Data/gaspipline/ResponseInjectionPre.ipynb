# %%
import numpy as np
import pandas as pd

# %%
responseInjectionPath = "./ModbusRTUfeatureSetsV2/Multiclass FeatureSets/MulticlassResponseInjectionV2.csv"

data = pd.read_csv(responseInjectionPath)

# %%
data.head(5)
# Out:
#   Address CommandResponse ControlMode ControlScheme   CRC  DataLength  \
# 0     0x4        Response           X             X  4536           4
# 1     0x4        Response           X             X  3439          19
# 2     0x4        Response           X             X  4536           4
# 3     0x4        Response           X             X  3533          19
# 4     0x4        Response           X             X  4536           4
#
#   FunctionCode InvalidDataLength InvalidFunctionCode  PIDCycleTime   ...    \
# 0         0x10                 X                   X             0   ...
# 1          0x3                 X                   X             0   ...
# 2         0x10                 X                   X             0   ...
# 3          0x3                 X                   X             0   ...
# 4         0x10                 X                   X             0   ...
#
#       SolenoidState  TimeInterval  deltaPIDCycleTime  deltaPIDDeadband  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29309 entries, 0 to 29308
# Data columns (total 27 columns):
# Address                29309 non-null object
# CommandResponse        29309 non-null object
# ControlMode            29309 non-null object
# ControlScheme          29309 non-null object
# CRC                    29309 non-null int64
# DataLength             29309 non-null int64
# FunctionCode           29309 non-null object
# InvalidDataLength      29309 non-null object
# InvalidFunctionCode    29309 non-null object
# PIDCycleTime           29309 non-null int64
# PIDDeadband            29309 non-null int64
# PIDGain                29309 non-null int64
# PIDRate                29309 non-null int64
# PIDReset               29309 non-null int64
# PipelinePSI            29309 non-null float64
# PumpState              29309 non-null object
# SetPoint               29309 non-null int64
# SolenoidState          29309 non-null object
# TimeInterval           29309 non-null int64
# ...

# %%
from collections import Counter
data.columns
# Out:
# Index(['Address', 'CommandResponse', 'ControlMode', 'ControlScheme', 'CRC',
#        'DataLength', 'FunctionCode', 'InvalidDataLength',
#        'InvalidFunctionCode', 'PIDCycleTime', 'PIDDeadband', 'PIDGain',
#        'PIDRate', 'PIDReset', 'PipelinePSI', 'PumpState', 'SetPoint',
#        'SolenoidState', 'TimeInterval', 'deltaPIDCycleTime',
#        'deltaPIDDeadband', 'deltaPIDGain', 'deltaPIDRate', 'deltaPIDReset',
#        'deltaPipelinePSI', 'deltaSetPoint', ' Label'],
#       dtype='object')

# %%
Counter(data[' Label'])
# Out:
# Counter({'Burst': 217,
#          'Fast': 225,
#          'Good': 28070,
#          'Negative': 119,
#          'Setpoint': 171,
#          'Single': 33,
#          'Slow': 306,
#          'Wave': 168})
